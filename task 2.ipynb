# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = pd.read_csv("E:/python_code/utech-python-ds-course/100 Sales Records.csv")
a
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
b = a.pivot(columns='Region', values='Total Profit')
b
# Out:
# Region      Asia  Australia and Oceania  Central America and the Caribbean  \
# 0            NaN               951410.5                                NaN
# 1            NaN                    NaN                          248406.36
# 2            NaN                    NaN                                NaN
# 3            NaN                    NaN                                NaN
# 4            NaN                    NaN                                NaN
# ..           ...                    ...                                ...
# 95           NaN                    NaN                                NaN
# 96      15103.47                    NaN                                NaN
# 97           NaN                    NaN                                NaN
# 98           NaN                    NaN                                NaN
# 99           NaN                    NaN                                NaN
#
# Region     Europe  Middle East and North Africa  North America  \
# ...

# %%
c = plt.figure()

d = c.add_subplot(1,1,1)

d.hist(a['Region'],bins = 7)

plt.title('Total Profit')

plt.show()

# %%
x = [5,7,8,7,2,17,2,9,4,11,12,9,6]
y = [99,86,87,88,111,86,103,87,94,78,77,85,86]


e = plt.figure()

f = e.add_subplot(1,1,1)


plt.scatter(x, y)
plt.show()

# %%
sns.boxplot(a['Total Profit'])
sns.despine()

# %%
g = a.groupby(['Region', 'Total Profit'])
g.size()
# Out:
# Region              Total Profit
# Asia                7828.12         1
#                     15103.47        1
#                     122819.06       1
#                     235601.16       1
#                     435499.20       1
#                                    ..
# Sub-Saharan Africa  696647.50       1
#                     766835.04       1
#                     778415.99       1
#                     889472.91       1
#                     1254472.05      1
# Length: 100, dtype: int64

# %%
h = a.drop_duplicates(['Total Revenue', 'Total Profit', 'Unit Price'])
print(h)
# Out:
#                                Region                Country        Item Type  \
# 0               Australia and Oceania                 Tuvalu        Baby Food
# 1   Central America and the Caribbean                Grenada           Cereal
# 2                              Europe                 Russia  Office Supplies
# 3                  Sub-Saharan Africa  Sao Tome and Principe           Fruits
# 4                  Sub-Saharan Africa                 Rwanda  Office Supplies
# ..                                ...                    ...              ...
# 95                 Sub-Saharan Africa                   Mali          Clothes
# 96                               Asia               Malaysia           Fruits
# 97                 Sub-Saharan Africa           Sierra Leone       Vegetables
# 98                      North America                 Mexico    Personal Care
# 99                 Sub-Saharan Africa             Mozambique        Household
#
# ...

# %%
i = a.groupby(['Total Profit'])
i.describe()
# Out:
#              Order ID                                                          \
#                 count         mean std          min          25%          50%
# Total Profit
# 1258.02           1.0  513417565.0 NaN  513417565.0  513417565.0  513417565.0
# 1621.93           1.0  816200339.0 NaN  816200339.0  816200339.0  816200339.0
# 5270.67           1.0  142278373.0 NaN  142278373.0  142278373.0  142278373.0
# 6841.38           1.0  617667090.0 NaN  617667090.0  617667090.0  617667090.0
# 7828.12           1.0  814711606.0 NaN  814711606.0  814711606.0  814711606.0
# ...               ...          ...  ..          ...          ...          ...
# 1487261.02        1.0  522840487.0 NaN  522840487.0  522840487.0  522840487.0
# 1505888.07        1.0  249693334.0 NaN  249693334.0  249693334.0  249693334.0
# 1541705.29        1.0  331438481.0 NaN  331438481.0  331438481.0  331438481.0
# 1678540.98        1.0  670854651.0 NaN  670854651.0  670854651.0  670854651.0
# ...
